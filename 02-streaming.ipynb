# %%
import numpy as np

# %%
import bokeh.models.sources 
import bokeh.plotting 
import bokeh.io
from bokeh.palettes import Category10_10 as palette

# %%
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bde76835-69f2-4eed-a819-d10d7e11a48a">Loading BokehJS ...</span>
#     </div>

# %%
# # uncomment and run this cell if not connected to the internet
# import bokeh.resources
# bokeh.plotting.output_notebook(resources=bokeh.resources.INLINE)

# %% [markdown]
# # Simulated Streaming Example

# %%
mu_x1, mu_y1 = np.random.randint(-40, 40, 2)
sigma_x1, sigma_y1 = np.random.randint(1, 25, 2)


my_fig = bokeh.plotting.figure(
    plot_width=400, 
    plot_height=400,
    x_axis_label='x',
    y_axis_label='y',
    x_range=(-100, 100),
    y_range=(-100, 100),
)

data1 = bokeh.models.sources.ColumnDataSource(data=dict(x=[], y=[]))

circle1 = my_fig.circle(
    "x", "y", 
    source=data1,
    color=palette[0],
    alpha=0.2,
)

handle = bokeh.io.show(my_fig, notebook_handle=True)

new_data1=dict(x=[], y=[])

step = 0
max_step = 1000  # arbitrary stop point for example

while step < max_step:
    new_data1['x'] = [np.random.normal(loc=mu_x1, scale=sigma_x1)]
    new_data1['y'] = [np.random.normal(loc=mu_y1, scale=sigma_y1)]
    
    data1.stream(new_data1)
    
    bokeh.io.push_notebook(handle=handle)
    step += 1
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="14582d8d-827f-40fe-9c3d-12bd9aa24600"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("14582d8d-827f-40fe-9c3d-12bd9aa24600");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("a7f538dc-75b9-4832-bc54-d0d8c69916db", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("14582d8d-827f-40fe-9c3d-12bd9aa24600");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '14582d8d-827f-40fe-9c3d-12bd9aa24600' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"13fcbf3a-fe5e-4b02-9e3a-7f756fd08c4c":{"roots":{"references":[{"attributes":{"plot":{"id":"eea9499a-ca29-475c-89e9-92921fe67624","subtype":"Figure","type":"Plot"}},"id":"d7d41b1e-e565-425c-872f-bbeb05368693","type":"SaveTool"},{"attributes":{"callback":null,"end":100,"start":-100},"id":"45301575-13bd-4786-9827-5bf80f3dfdad","type":"Range1d"},{"attributes":{"plot":{"id":"eea9499a-ca29-475c-89e9-92921fe67624","subtype":"Figure","type":"Plot"}},"id":"24436566-a840-408c-a3ba-9b386de34f4e","type":"ResetTool"},{"attributes":{"plot":{"id":"eea9499a-ca29-475c-89e9-92921fe67624","subtype":"Figure","type":"Plot"}},"id":"93fc5b5b-8f33-460f-9cfd-ecf4d6f5e8f7","type":"HelpTool"},{"attributes":{},"id":"95ba56eb-906e-48aa-87c4-50d48f60d5cd","type":"ToolEvents"},{"attributes":{"plot":null,"text":""},"id":"27fddac5-2729-4ff8-92ed-a2c68350d7cd","type":"Title"},{"attributes":{},"id":"65720f1e-a762-4a5a-a951-d1874da1263e","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"
# %% [markdown]
# ## Test yourself:

# %% [markdown]
# ### Can you guess what the mean and standard deviation values are for each direction, x, and y?
#
# Double click on this cell to insert your answers
#
# - $\mu_x$: [your answer here]
# - $\sigma_x$: [your answer here]
# - $\mu_y$: [your answer here]
# - $\sigma_y$: [your answer here]

# %% [markdown]
# Run the following cell to see how close you are.

# %%
print('mu x1: {}\t sigma x1: {}'.format(mu_x1, sigma_x1))
print('mu y1: {}\t sigma y1: {}'.format(mu_y1, sigma_y1))
# Out:
# mu x1: -35	 sigma x1: 17
# mu y1: 19	 sigma y1: 13

# %% [markdown]
# # Exercise
# Copy the above code, then make it so that on each update, a point for a second Normal Gaussian Distribution gets added to the plot.  I recommend using a different color for the second distribution.

# %%
mu_x1, mu_y1, mu_x2, mu_y2 = np.random.randint(-40, 40, 4)
sigma_x1, sigma_y1, sigma_x2, sigma_y2 = np.random.randint(1, 25, 4)



my_fig = bokeh.plotting.figure(
    plot_width=400, 
    plot_height=400,
    x_axis_label='x',
    y_axis_label='y',
    x_range=(-100, 100),
    y_range=(-100, 100),
)

data1 = bokeh.models.sources.ColumnDataSource(data=dict(x=[], y=[]))
data2 = bokeh.models.sources.ColumnDataSource(data=dict(x=[], y=[]))

circle1 = my_fig.circle(
    "x", "y", 
    source=data1,
    color=palette[0],
    alpha=0.2,
)

circle2 = my_fig.circle(
    "x", "y", 
    source=data2,
    color=palette[1],
    alpha=0.4,
)

handle = bokeh.io.show(my_fig, notebook_handle=True)

new_data1=dict(x=[], y=[])
new_data2=dict(x=[], y=[])

step = 0
max_step = 1000  # arbitrary stop point for example

while step < max_step:
    new_data1['x'] = [np.random.normal(loc=mu_x1, scale=sigma_x1)]
    new_data1['y'] = [np.random.normal(loc=mu_y1, scale=sigma_y1)]
    new_data2['x'] = [np.random.normal(loc=mu_x2, scale=sigma_x2)]
    new_data2['y'] = [np.random.normal(loc=mu_y2, scale=sigma_y2)]
    
    data1.stream(new_data1)
    data2.stream(new_data2)
    
    bokeh.io.push_notebook(handle=handle)
    step += 1
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8834e69b-d9a2-47d5-90c9-45fb701e76bb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8834e69b-d9a2-47d5-90c9-45fb701e76bb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("086ed988-e6a4-4f6a-a01d-06889a04af9d", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8834e69b-d9a2-47d5-90c9-45fb701e76bb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8834e69b-d9a2-47d5-90c9-45fb701e76bb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fec64402-9345-44e4-91fd-08262ddae33a":{"roots":{"references":[{"attributes":{},"id":"7538c32c-5928-475b-8f90-eec60fdb9595","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[],"y":[]}},"id":"c459cbb9-807f-4850-b272-e8ada5342801","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"3c3934d4-c4bc-4ab8-9f7a-657603eba096","subtype":"Figure","type":"Plot"}},"id":"c305c742-d6b0-4c45-ada8-11ff01d00682","type":"ResetTool"},{"attributes":{"plot":{"id":"3c3934d4-c4bc-4ab8-9f7a-657603eba096","subtype":"Figure","type":"Plot"}},"id":"40c99deb-9499-4d43-9dde-e5d640ea2b0c","type":"SaveTool"},{"attributes":{"callback":null,"end":100,"start":-100},"id":"7d069a7e-b4af-418b-8d06-b46cbf1e6f20","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.4},"fill_color":{"value":"#ff7f0e"},"line_alpha":{
type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"97a819fa-b9d4-4650-8eab-cebcbfb61d0a","type":"PanTool"},{"id":"ba17b714-8cf8-43f9-8968-736d7b024c69","type":"WheelZoomTool"},{"id":"401fc2de-2a67-405b-aa27-f311409fc28c","type":"BoxZoomTool"},{"id":"40c99deb-9499-4d43-9dde-e5d640ea2b0c","type":"SaveTool"},{"id":"c305c742-d6b0-4c45-ada8-11ff01d00682","type":"ResetTool"},{"id":"99ae4db7-5018-45df-9708-ef3b3de857b5","type":"HelpTool"}]},"id":"6379b422-dd24-4c19-ac77-48018ea2722d","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#1f77b4"},"line_ ...

# %% [markdown]
# Run the following cell to see one possible solution.

# %%
# %load solutions/02_exercise.py
mu_x1, mu_y1, mu_x2, mu_y2 = np.random.randint(-40, 40, 4)
sigma_x1, sigma_y1, sigma_x2, sigma_y2 = np.random.randint(1, 25, 4)


my_fig = bokeh.plotting.figure(
    plot_width=400,
    plot_height=400,
    x_axis_label='x',
    y_axis_label='y',
    x_range=(-100, 100),
    y_range=(-100, 100),
)

data1 = bokeh.models.sources.ColumnDataSource(data=dict(x=[], y=[]))
data2 = bokeh.models.sources.ColumnDataSource(data=dict(x=[], y=[]))

circle1 = my_fig.circle(
    "x", "y",
    source=data1,
    color=palette[0],
    alpha=0.2,
)

circle2 = my_fig.circle(
    "x", "y",
    source=data2,
    color=palette[1],
    alpha=0.2,
)

handle = bokeh.io.show(my_fig, notebook_handle=True)

new_data1=dict(x=[], y=[])
new_data2=dict(x=[], y=[])

step = 0
max_step = 1000  # arbitrary stop point for example

while step < max_step:
    new_data1['x'] = [np.random.normal(loc=mu_x1, scale=sigma_x1)]
    new_data1['y'] = [np.random.normal(loc=mu_y1, scale=sigma_y1)]
    new_data2['x'] = [np.random.normal(loc=mu_x2, scale=sigma_x2)]
    new_data2['y'] = [np.random.normal(loc=mu_y2, scale=sigma_y2)]

    data1.stream(new_data1)
    data2.stream(new_data2)

    bokeh.io.push_notebook(handle=handle)
    step += 1

# %% [markdown]
# ## Test yourself:

# %% [markdown]
# ### Can you guess what the mean and standard deviation values are for each direction, x1, x2, y1, and y2?
#
# Double click on this cell to insert your answers
#
# - $\mu_x1$: [your answer here]
# - $\sigma_x1$: 80
# - $\mu_y1$: [your answer here]
# - $\sigma_y1$: 90
# - $\mu_x2$: [your answer here]
# - $\sigma_x2$: 70
# - $\mu_y2$: [your answer here]
# - $\sigma_y2$: 8

# %% [markdown]
# Run the following cell to see how close you are.

# %%
print('mu x1: {}\t sigma x1: {}'.format(mu_x1, sigma_x1))
print('mu y1: {}\t sigma y1: {}'.format(mu_y1, sigma_y1))
print('mu x2: {}\t sigma x2: {}'.format(mu_x2, sigma_x2))
print('mu y2: {}\t sigma y2: {}'.format(mu_y2, sigma_y2))
# Out:
# mu x1: -1	 sigma x1: 15
# mu y1: -16	 sigma y1: 2
# mu x2: -38	 sigma x2: 21
# mu y2: -25	 sigma y2: 20
