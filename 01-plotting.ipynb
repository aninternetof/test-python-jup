# %% [markdown]
# # Imports
#
# When using the [`bokeh.plotting`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html) interface, here are a few of the most common ones we will use:
# * Use the [`figure`](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.figure) function to  create new plot objects to work with.
# * Call the functions [`output_file`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_file), [`output_notebook`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_notebook), and [`output_server`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_server) (possibly in combination) to tell Bokeh how to display or save output.
# * Execute [`show`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.show) and  [`save`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.save) to display or save plots and layouts.

# %%
import bokeh.plotting

# %% [markdown]
# Load the bokeh JavaScript layer from the web.

# %%
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b507a3d7-6881-42da-8d78-ec2f40550344">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# If not connected to the internet, you can get the JavaScript library inline by running
#
# ```
# import bokeh.resources
# bokeh.plotting.output_notebook(resources=bokeh.resources.INLINE)
# ```

# %%
# # uncomment and run this cell if not connected to the internet
# import bokeh.resources
# bokeh.plotting.output_notebook(resources=bokeh.resources.INLINE)

# %% [markdown]
# Bokeh incorporates many [palettes](http://bokeh.pydata.org/en/latest/docs/reference/palettes.html#bokeh-palettes) for presenting your data.  The following import method makes it easy to switch out which palette you are using.

# %%
from bokeh.palettes import Category10_10 as palette
# # switching palettes is as easy as replacing which you import
# from bokeh.palettes import Colorblind_7 as palette

# %% [markdown]
# Palettes are simply a list of color hex strings.

# %%
print(palette)
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# You can also use many color names, e.g., `'blue'`, `'red'`, `'yellow'`, `'firebrick'`, etc.  Feel free to explore.

# %%
import numpy as np

# %% [markdown]
# We will use SciPy to create some sample data.

# %%
import scipy.stats

# %% [markdown]
# # Sample plot

# %% [markdown]
# Bokeh expects data as either a **single value**, or a **series of values**, e.g., list, set, NumPy array, Pandas DataFrame column.  We will often use NumPy arrays.
#
# Lets create some sample data.  Throughout this tutorial, we will use the [normal (or Gaussian) distribution](https://en.wikipedia.org/wiki/Normal_distribution) for out sample data.  The Gaussian distribution is defined as

# %% [markdown]
# $$f(x | \mu, \sigma^2) = \frac{1}{\sqrt{2\pi\sigma^2}} \,\exp\left({-\frac{(x-\mu)^2}{2\sigma^2}}\right)$$

# %% [markdown]
# where $\mu$ is the mean value, and $\sigma$ is the standard deviation.
#
# SciPy provides [`scipy.stats.norm`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html) which include many functions related to the Gaussian distribution.  Here is a simple wrapper of the probability density function (pdf).

# %%
def gaussian(x_array, mu, sigma):
    pdf = scipy.stats.norm.pdf(x_array, loc=mu, scale=sigma)
    return pdf

# %% [markdown]
# We will define 3 Gaussian distributions:
# 1. $\mu=10$, $\sigma=4$
# 2. $\mu=15$, $\sigma=1$
# 3. $\mu=8$, $\sigma=2$

# %%
x = np.linspace(0, 20, 100)
y1 = gaussian(x, 10, 4)
y2 = gaussian(x, 15, 1)
y3 = gaussian(x, 8, 2)

# %%
p = bokeh.plotting.figure()
p.diamond(x, y1)
bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="95a4b4ad-c794-4710-a438-863872451033"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("95a4b4ad-c794-4710-a438-863872451033");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("95a4b4ad-c794-4710-a438-863872451033");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '95a4b4ad-c794-4710-a438-863872451033' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6df8edc3-b4f7-4362-9d19-ca3f2e194fd0":{"roots":{"references":[{"attributes":{"callback":null},"id":"15635561-ad0a-4ec1-b336-fbfb663f8cf1","type":"DataRange1d"},{"attributes":{},"id":"af4eae0c-782d-4151-838b-8bc398de42b3","type":"BasicTickFormatter"},{"attributes":{},"id":"0386cd77-21a8-4df3-86b9-9b8a2f8ded67","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"
},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"scree ...

# %% [markdown]
# After just 3 lines of code, we have a reasonable plot of our data with several interactions availble by default.  ### Explore
# Go through each of the tools on the right side figuring out what each does.
#
# # Quiz
# 1\. What do each of the following do?
#
# ￼￼  <img src="assets/Bokeh.png" width="20"/>
#   <img src="assets/Pan.png" width="20"/>
#   <img src="assets/BoxZoom.png" width="20"/>
#   <img src="assets/WheelZoom.png" width="20"/>
#   <img src="assets/Save.png" width="20"/>
#   <img src="assets/Reset.png" width="20"/>
#   <img src="assets/Help.png" width="20"/>
#
# 2\. Where do you go to learn about configuring plot tools?
#
# 3\. Name one additional tool that is not one of the default tools?

# %% [markdown]
# In addition to `tools`, `figure()` and `diamond()` have several other `kwargs` you can use to adjust the plotting results.  Lets see some of these in use.

# %%
p = bokeh.plotting.figure(
    title='Demo Plot',
    x_axis_label='x',
    y_axis_label='f(x)',
    width=500, height=350,
    x_range=(0, 20),
    y_range=(-0.05, 0.12),
)

p.diamond(x, y1, 
          line_color=palette[0], 
          fill_color=palette[1],
          line_alpha=y1/y1.max(), # oscillate from 0 to 1 (y min to max)
          fill_alpha=(1-y1/y1.max()), # oscillate from 1 to 0 (y min to max)
          legend='m=10, s=4', 
          size=x/1.5)

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9854a241-7f34-4fb5-9e03-39a150b54996"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9854a241-7f34-4fb5-9e03-39a150b54996");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9854a241-7f34-4fb5-9e03-39a150b54996");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9854a241-7f34-4fb5-9e03-39a150b54996' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"966bec2e-2355-4d04-921f-963cbde13bc6":{"roots":{"references":[{"attributes":{"callback":null,"end":0.12,"start":-0.05},"id":"d69bab51-48d0-421c-8e5d-47dc9d8119be","type":"Range1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b7cb6661-2735-47e2-997e-32359a8164c1","type":"PanTool"},{"id":"f34c11ad-26e4-472d-8295-6629ad25b27e","type":"WheelZoomTool"},{"id":"dcb008c9-d726-47ec-8e0d-3aa248e5d5c7","type":"BoxZoomTool"},{"id":"e4913093-dd59-40ac-a032-3376386c8834","type":"SaveTool"},{"id":"6c2126d1-b20f-4f91-baa1-e3d2d1c8db92","type":"ResetTool"},{"id":"bc65bec9-a4fa-4cbf-b6ee-ebecf88ff997","type":"HelpTool"}]},"id":"e1399f2e-d73b-4542-84bd-71edfb0e4fd5","type":"Toolbar"},{"attributes":{},"id":"a345ef99-a059-4056-9398-a9f480fb8c85","type":"ToolEvents"},{"attributes":{},"id":"29c25564-5793-48de-a467-97c54b789039","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"02b60c2a-a69b-4b26-86e9-ad77885784f5","type":"Diamond"},{"attributes":{"plot":{"id":"5195d506-e9ef-4101-8365-83b873c7c4b3","subtype":"Figure","type":"Plot"}},"id":"f34c11ad-26e4-472d-8295-6629ad25b27e","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":20},"id":"bce065bf-f24e-4564-b3bb-7305f9f45c4e","type":"Range1d"},{"attributes":{"plot":null,"text":"Demo Plot"},"id":"1c4f3fb1-60fe-49c4-985f-6971a452b6f6","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#ff7f0e"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b278ce7c-afe8-47d4-a644-15b4ee3ecd36","type":"Diamond"},{"attributes":{"data_source":{"id":"68cb5276-6819-4997-a55f-fb36e13421bc","type":"ColumnDataSource"},"glyph":{"id":"b278ce7c-afe8-47d4-a644-15b4ee3ecd36","type":"Diamond"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"02b60c2a-a69b-4b26-86e9-ad77885784f5","type":"Diamond"},"selection_glyph":null},"id":"77090278-98c7-4c17-949e-48654269dffd","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"ea8a750d-5699-4d86-bd6c-2d0ff5cc9cc3","type":"LinearAxis"}],"left":[{"id":"538a76c9-8e38-4567-8959-4ea96cac857c","type":"LinearAxis"}],"plot_height":350,"plot_width":500,"renderers":[{"id":"ea8a750d-5699-4d86-bd6c-2d0ff5cc9cc3","type":"LinearAxis"},{"id":"78bce457-6858-4cc1-beda-997fccffaa6c","type":"Grid"},{"id":"538a76c9-8e38-4567-8959-4ea96cac857c","type":"LinearAxis"},{"id":"ae03b971-f760-4cb5-bcb6-641316f50ccb","type":"Grid"},{"id":"f9afdc82-343c-4054-8a08-5b40c6b821ce","type":"BoxAnnotation"},{"id":"eea0d41f-648c-4cf4-9226-42c7213cc09d","type":"Legend"},{"id":"77090278-98c7-4c17-949e-48654269dffd","type":"GlyphRenderer"}],"title":{"id":"1c4f3fb1-60fe-49c4-985f-6971a452b6f6","type":"Title"},"tool_events":{"id":"a345ef99-a059-4056-9398-a9f480fb8c85","type":"ToolEvents"},"toolbar":{"id":"e1399f2e-d73b-4542-84bd-71edfb0e4fd5","type":"Toolbar"},"x_range":{"id":"bce065bf-f24e-4564-b3bb-7305f9f45c4e","type":"Range1d"},"x_scale":{"id":"c50e0e86-0c73-4e8c-9ecb-ba424eee9b52","type":"LinearScale"},"y_range":{"id":"d69bab51-48d0-421c-8e5d-47dc9d8119be","type":"Range1d"},"y_scale":{"id":"13ed43c6-3586-48b2-a609-8df63aea1a22","type":"LinearScale"}},"id":"5195d506-e9ef-4101-8365-83b873c7c4b3","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"x","formatter":{"id":"29c25564-5793-48de-a467-97c54b789039","type":"BasicTickFormatter"},"plot":{"id":"5195d506-e9ef-4101-8365-83b873c7c4b3","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d96cba6-67b0-4347-bf1f-974564a52f73","type":"BasicTicker"}},"id":"ea8a750d-5699-4d86-bd6c-2d0ff5cc9cc3","type":"LinearAxis"},{"attributes":{"items":[{"id":"6f952faf-c27c-4d41-8465-9c4619092480","type":"LegendItem"}],"plot":{"i ...

# %% [markdown]
# Note that you can use `color` to set both the `line_color` and `fill_color`.  Similarly, `alpha` sets both the `line_alpha` and `fill_alpha`.

# %%
p = bokeh.plotting.figure(
    title='Demo Plot',
    x_axis_label='x',
    y_axis_label='f(x)',
    width=500, height=350,
    x_range=(0, 20),
    y_range=(-0.05, 0.12),
)

p.diamond(
    x, y1, 
    color=palette[0], 
    alpha=y1/y1.max(), # oscillate from 0 to 1 (y min to max)
    legend='m=10 s=4', 
    size=x/1.5)

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fa2223a5-d326-4f11-936c-75270272b04a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fa2223a5-d326-4f11-936c-75270272b04a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fa2223a5-d326-4f11-936c-75270272b04a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fa2223a5-d326-4f11-936c-75270272b04a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0b835a12-2c1f-4ea8-b715-fa73f3308743":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f2daac8e-594c-42ea-ab62-4b62c83bd24f","type":"BoxAnnotation"},{"attributes":{"callback":null,"end
type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"31ec629e-c629-41e2-a9f1-9676160aa88f","type":"Diamond"},{"attributes":{"items":[{"id":"347cfe8 ...

# %% [markdown]
# # Quiz

# %% [markdown]
# Double click on this cell to insert your answers.
#
# ### 1. Which settings, both args and kwargs, did we see for `bokeh.plotting.figure`?
#
# [Your answer here]
#
# ### 2. Which settings, both args and kwargs, did we see for `diamond`?
#
# [Your answer here]
#
# ### 3. In the above plots, which settings used a single value and which used a series of values?
#
# [Your answer here]

# %% [markdown]
# ### Run the following cell to see the answers

# %%
solution_fname = 'solutions/01_quiz.txt'
with open(solution_fname, 'r') as f:
    solution = f.read()
print(solution)
# Out:
# 1. Which inputs did we see for `bokeh.plotting.figure`?
#
# kwargs:
#     title
#     x_axis_label
#     y_axis_label
#     width
#     height
#     x_range
#     y_range
#
# 2. Which inputs did we see for `diamond`?
#
# args:
#     x-values
#     y-values
#
# kwargs:
#     color
#     line_color
#     fill_color
#     alpha
#     line_alpha
#     fill_alpha
#     legend
#     size
#
# 3. In the diamond plots, which settings used a single value and which used a
# series of values?
#
# single values:
#     color
#     line_color
#     fill_color
#     legend
#
# series of values:
#     alpha
#     line_alpha
#     fill_alpha
#     size

# %% [markdown]
# </table><p>There are many marker types available in Bokeh, you can see details and
# example plots for all of them in the reference guide by clicking on entries in the list below:</p>
# <table class="hlist" style="float:left"><tr><td><ul>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.asterisk" title="bokeh.plotting.Figure.asterisk"><code class="xref py py-func docutils literal"><span class="pre">asterisk()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle" title="bokeh.plotting.Figure.circle"><code class="xref py py-func docutils literal"><span class="pre">circle()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle_cross" title="bokeh.plotting.Figure.circle_cross"><code class="xref py py-func docutils literal"><span class="pre">circle_cross()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle_x" title="bokeh.plotting.Figure.circle_x"><code class="xref py py-func docutils literal"><span class="pre">circle_x()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.cross" title="bokeh.plotting.Figure.cross"><code class="xref py py-func docutils literal"><span class="pre">cross()</span></code></a></li>
# </ul>
# </td><td><ul>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.diamond" title="bokeh.plotting.Figure.diamond"><code class="xref py py-func docutils literal"><span class="pre">diamond()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.diamond_cross" title="bokeh.plotting.Figure.diamond_cross"><code class="xref py py-func docutils literal"><span class="pre">diamond_cross()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.inverted_triangle" title="bokeh.plotting.Figure.inverted_triangle"><code class="xref py py-func docutils literal"><span class="pre">inverted_triangle()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square" title="bokeh.plotting.Figure.square"><code class="xref py py-func docutils literal"><span class="pre">square()</span></code></a></li>
# </ul>
# </td><td><ul>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square_cross" title="bokeh.plotting.Figure.square_cross"><code class="xref py py-func docutils literal"><span class="pre">square_cross()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square_x" title="bokeh.plotting.Figure.square_x"><code class="xref py py-func docutils literal"><span class="pre">square_x()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.triangle" title="bokeh.plotting.Figure.triangle"><code class="xref py py-func docutils literal"><span class="pre">triangle()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.x" title="bokeh.plotting.Figure.x"><code class="xref py py-func docutils literal"><span class="pre">x()</span></code></a></li>
# </ul>
# </td></tr></table>

# %% [markdown]
# Also, there is a similar command to draw a `line()`, with the added kwarg: `line_width`.

# %% [markdown]
# # Exercise
# Plot all three data sets, `y1`, `y2`, and `y3`, each as a function of the `x` array.  For each data set, use a different entry for each of the following:
# - `color` (or `line_color` and `fill_color` separately)
# - `alpha` (or `line_alpha` and `fill_alpha` separately)
# - `legend`
#
# Also, try using the `line()` option for one of the data sets and two different marker types for the other two data sets (e.g. `diamond()`, `asterisk()`, `circle()`, etc).
#
# Try using a mix of single values and series of values.

# %%
p = bokeh.plotting.figure(
    title='Demo Plot',
    x_axis_label='x',
    y_axis_label='f(x)',
    width=500, height=350,
    x_range=(0, 20),
    y_range=(-0.05, max([max(y) for y in (y1,y2,y3)])),
)

p.diamond(x, y1, 
          line_color=palette[0], 
          fill_color=palette[1],
          line_alpha=y1/y1.max(), # oscillate from 0 to 1 (y min to max)
          fill_alpha=(1-y1/y1.max()), # oscillate from 1 to 0 (y min to max)
          legend='m=10, s=4', 
          size=x/1.5)

p.circle(x, y2, 
          line_color=palette[2], 
          fill_color=palette[3],
          legend='m=15, s=1',
          radius=y2,
        )

p.x(x, y3, 
          line_color=palette[4], 
          fill_color=palette[5],
          legend='m=8, s=2',
         )

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ded9a592-cecb-4509-bbe8-93203ea8dd1a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ded9a592-cecb-4509-bbe8-93203ea8dd1a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ded9a592-cecb-4509-bbe8-93203ea8dd1a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ded9a592-cecb-4509-bbe8-93203ea8dd1a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bf7bd550-fb7a-4bee-a77a-80fb31f039f7":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e2d6ef3-ee48-4076-a675-7830e10a616b","type":"Diamond"},{"attributes":{},"id":"29f8e4cb-dc6b-4a28-9197-8aff5a4879a5","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#ff7f0e"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"576faa9b-ca8d-4d35-a641-e13e3b6b79e8","type":"Diamond"},{"attributes":{"callback":null,"end":0.39843380169134646,"start":-0.05},"id":"17742690-de96-456c-90d3-23403d293584","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"00812143-e365-4564-a9b9-3bfd0a6f27f8","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Demo Plot"},"id":"44e1ae2f-9362-4a0e-80a5-3276d006e790","type":"Title"},{"attributes":{"axis_label":"f(x)","formatter":{"id":"b4df1ea9-3781-4527-873a-fb3b6c7f755c","type":"BasicTickFormatter"},"plot":{"id":"9e548870-4771-4011-8036-d7e21cd45399","subtype":"Figure","type":"Plot"},"ticker":{"id":"8249516a-d7ae-4611-8efc-333e1c39114b","type":"BasicTicker"}},"id":"37ed8cd9-7e49-41ee-b306-5d766c697d36","type":"LinearAxis"},{"attributes":{"axis_label":"x","formatter":{"id":"510bcf8b-96f0-4234-8c4a-0ead05daf6c3","type":"BasicTickFormatter"},"plot":{"id":"9e548870-4771-4011-8036-d7e21cd45399","subtype":"Figure","type":"Plot"},"ticker":{"id":"b689e0b3-4467-42f1-acd2-0e0502f74496","type":"BasicTicker"}},"id":"1893ad59-50a2-42dc-b4ee-b04a0249b407","type":"LinearAxis"},{"attributes":{},"id":"71c880d6-c099-4a26-8296-79a59fb41001","type":"LinearScale"},{"attributes":{"data_source":{"id":"00812143-e365-4564-a9b9-3bfd0a6f27f8","type":"ColumnDataSource"},"glyph":{"id":"097ced0d-c41e-433a-a6b8-d5029dd161f5","type":"X"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bc7c02a9-7878-4f44-89ca-23c470bf7f9c","type":"X"},"selection_glyph":null},"id":"0295f82c-219c-4519-a014-719d181ffcda","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"9e548870-4771-4011-8036-d7e21cd45399","subtype":"Figure","type":"Plot"},"ticker":{"id":"b689e0b3-4467-42f1-acd2-0e0502f74496","type":"BasicTicker"}},"id":"4c61994f-2a1e-457c-8ff5-1b500d54220a","type":"Grid"},{"attributes":{"label":{"value":"m=10, s=4"},"renderers":[{"id":"8a00a7b4-0419-4a2e-83e9-b8b4b5a6f8d0","type":"GlyphRenderer"}]},"id":"ff87c523-970c-4226-9aac-dbc87054e9cf","type":"LegendItem"},{"attributes":{"plot":{"id":"9e548870-4771-4011-8036-d7e21cd45399","subtype":"Figure","type":"Plot"}},"id":"9f238ea5-f11e-44e1-b830-55f230f63f6c","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"09b1dd3f-7c2c-491e-9416-fd8dd4c123c9","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"9e548870-4771-4011-8036-d7e21cd45399","subtype":"Figure","type":"Plot"},"ticker":{"id":"8249516a-d7ae-4611-8efc-333e1c39114b","type":"BasicTicker"}},"id":"9d626a3e-1381-4841-b750-afe3aa7f7669","type":"Grid"},{"attributes":{},"id":"b4df1ea9-3781-4527-873a-fb3b6c7f755c","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"#8c564b"},"line_color":{"value":"#9467bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"097ced0d-c41e-433a-a6b8-d5029dd161f5","type":"X"},{"attributes":{},"id":"8249516a-d7ae-4611-8efc-333e1c39114b","type":"BasicTicker"},{"attributes":{},"id":"510bcf8b ...

# %% [markdown]
# Run the following cell to see one possible solution.

# %%
# %load solutions/01_exercise.py

# %% [markdown]
# # Read the [Docs](http://bokeh.pydata.org)
#   - [Plotting with Basic Glyphs](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html)
#   - [Styling Visual Attributes](http://bokeh.pydata.org/en/latest/docs/user_guide/styling.html)

# %%
p.circle?
