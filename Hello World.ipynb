# %% [markdown]
# # Welcome
# asdfasdf

# %%
print("Hello world!")

# %%
import numpy as np
import bokeh.models.sources 
import bokeh.plotting 
import bokeh.io
from bokeh.palettes import Category10_10 as palette
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7722f62c-696c-4f17-9f4c-c72ebe8d21f3">Loading BokehJS ...</span>
#     </div>

# %%
mu_x1, mu_y1 = np.random.randint(-40, 40, 2)
sigma_x1, sigma_y1 = np.random.randint(1, 25, 2)


my_fig = bokeh.plotting.figure(
    plot_width=400, 
    plot_height=400,
    x_axis_label='x',
    y_axis_label='y',
    x_range=(-100, 100),
    y_range=(-100, 100),
)

data1 = bokeh.models.sources.ColumnDataSource(data=dict(x=[], y=[]))

circle1 = my_fig.circle(
    "x", "y", 
    source=data1,
    color=palette[0],
    alpha=0.2,
)

handle = bokeh.io.show(my_fig, notebook_handle=True)

new_data1=dict(x=[], y=[])

step = 0
max_step = 1000  # arbitrary stop point for example

while step < max_step:
    new_data1['x'] = [np.random.normal(loc=mu_x1, scale=sigma_x1)]
    new_data1['y'] = [np.random.normal(loc=mu_y1, scale=sigma_y1)]
    
    data1.stream(new_data1)
    
    bokeh.io.push_notebook(handle=handle)
    step += 1
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2a613a45-adce-4387-bd9d-9d8691e3503a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2a613a45-adce-4387-bd9d-9d8691e3503a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("a56faf77-77ec-48a3-8673-787e2578b554", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2a613a45-adce-4387-bd9d-9d8691e3503a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2a613a45-adce-4387-bd9d-9d8691e3503a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3c852d26-23b2-4433-81ec-00ae52d0735b":{"roots":{"references":[{"attributes":{},"id":"68d16e74-7377-4ff4-a4ce-8a694dd73570","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c62d73af-7d5c-4d40-81c2-42a2deee3b7a","subtype":"Figure","type":"Plot"}},"id":"a5a10231-4d7d-4093-8db3-bc69ffa8a45d","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"c62d73af-7d5c-4d40-81c2-42a2deee3b7a","subtype":"Figure","type":"Plot"}},"id":"14d6854a-d078-4228-be68-437092005edb","type":"HelpTool"},{"attributes":{"plot":null,"text":""},"id":"5a4b3415-4246-4917-a9fe-4a31f81022f3","type":"Title"},{"attributes":{"callback":null,"end":100,"start":-100},"id":"5703190d-8fab-4b5c-9769-c3abf373ad55","type":"Range1d"},{"attributes":{"plot":{"id":"c62d73af-7d5c-4d40-81c2-42a2deee3b7a","subtype":"Figure","type":"Plot"}},"id":"38fe3d1f-77ca-4d52-b16e-6fe05e14e491","type":"ResetTool"},{"attributes":{},"id":"d28e73a7-5639-4d50-a26c-46e1089f4e80","type":"LinearScale"},{"attributes":{},"id":"f0c67bc0-0cb2-4240-800d-1dce1e1340c4","type":"LinearScale"},{"attributes":{"axis_label":"x","formatter":{"id":"489cf710-563b-4654-9b97-80a48fe12b76","type":"BasicTickFormatter"},"plot":{"id":"c62d73af-7d5c-4d40-81c2-42a2deee3b7a","subtype":"Figure","type":"Plot"},"ticker":{"id":"9979a4d4-2dc5-4837-b0db-536d1925b9c6","type":"BasicTicker"}},"id":"dc9337e8-8be1-481e-ab91-f84582cf2f31","type":"LinearAxis"},{"attributes":{"data_source":{"id":"a5ab25a3-29c3-4bd2-ba68-1ea987084923","type":"ColumnDataSource"},"glyph":{"id":"9b9f3ed8-90cb-46cd-965f-1c39804ca6b0","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0cfff517-695a-4b6e-84c6-4fde3fa77dd2","type":"Circle"},"selection_glyph":null},"id":"dfac0026-5456-4c59-a050-dc4617ab0b71","type":"GlyphRenderer"},{"attributes":{},"id":"9979a4d4-2dc5-4837-b0db-536d1925b9c6","type":"BasicTicker"},{"attributes":{"plot":{"id":"c62d73af-7d5c-4d40-81c2-42a2deee3b7a","subtype":"Figure","type":"Plot"},"ticker":{"id":"9979a4d4-2dc5-4837-b0db-536d1925b9c6","type":"BasicTicker"}},"id":"272f22e0-a26f-4c7a-a35d-7ee0ed0568dc","type":"Grid"},{"attributes":{"axis_label":"y","formatter":{"id":"68d16e74-7377-4ff4-a4ce-8a694dd73570","type":"BasicTickFormatter"},"plot":{"id":"c62d73af-7d5c-4d40-81c2-42a2deee3b7a","subtype":"Figure","type":"Plot"},"ticker":{"id":"7373d515-6afb-425b-8e53-aebe9b1ee87d","type":"BasicTicker"}},"id":"a10b2e24-b092-4f5b-902f-16177b28529a","type":"LinearAxis"},{"attributes":{},"id":"7373d515-6afb-425b-8e53-aebe9b1ee87d","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[],"y":[]}},"id":"a5ab25a3-29c3-4bd2-ba68-1ea987084923","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"c62d73af-7d5c-4d40-81c2-42a2deee3b7a","subtype":"Figure","type":"Plot"},"ticker":{"id":"7373d515-6afb-425b-8e53-aebe9b1ee87d","type":"BasicTicker"}},"id":"5078d8c8-314b-49f3-b9c6-8a95ae0a6a33","type":"Grid"},{"attributes":{"overlay":{"id":"70dbd21c-e1dc-413a-9518-cd9407541fd1","type":"BoxAnnotation"},"plot":{"id":"c62d73af-7d5c-4d40-81c2-42a2deee3b7a","subtype":"Figure","type":"Plot"}},"id":"41c0b4b0-9948-44d8-950b-ea7a3ef9f11e","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0cfff517-695a-4b6e-84c6-4fde3fa77dd2","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"70dbd21c-e1dc-413a-9518-cd9407541fd1","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.2},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b9f3ed8-9 ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
